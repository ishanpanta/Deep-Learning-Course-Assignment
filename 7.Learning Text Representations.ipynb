# %% [markdown]
# # Learning Text Representation
# Neural networks require inputs only in numbers. So when we have textual
# data, we convert them into numeric or vector representation and feed it to the
# network.

# %% [markdown]
# **word2vec** algorithm converts the textual input to a meaningful vector. They learn the semantic vector representation for each word in the given input text.Word2vec is one of the most popular and widely used models for generating
# the word embeddings. Word embeddings
# are the vector representations of words in a vector space. The embedding
# generated by the word2vec model captures the syntactic and semantic
# meanings of a word. Having a meaningful vector representation of a word
# helps the neural network to understand the word better.

# %%
import numpy as np

# %%
#Single context CBOW ()
def Single_context_CBOW(x, label, W1, W2, loss):
  #forward propagation
  h = np.dot(W1.T, x)
  u = np.dot(W2.T, h)
  y_pred = softmax(u)
  #error
  e = -label + y_pred
  #backward propagation
  dW2 = np.outer(h, e)
  dW1 = np.outer(x, np.dot(W2.T, e))
  #update weights
  W1 = W1 - lr * dW1
  W2 = W2 - lr * dW2
  #loss function
  loss += -float(u[label == 1]) + np.log(np.sum(np.exp(u)))
  return W1, W2, loss

# %% [markdown]
# # Building the word2vec model using gensim

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import warnings
warnings.filterwarnings(action='ignore')
#data processing
import pandas as pd
import re
from nltk.corpus import stopwords
stopWords = stopwords.words('english')
#modelling
from gensim.models import Word2Vec
from gensim.models import Phrases
from gensim.models.phrases import Phraser

# %%
data = pd.read_csv('/content/text.csv',header=None)

# %%
data.head()
# Out:
#                                                    0
# 0  room kind clean strong smell dogs. generally a...
# 1  stayed crown plaza april april . staff friendl...
# 2  booked hotel hotwire lowest price could find. ...
# 3  stayed husband sons way alaska cruise. loved h...
# 4  girlfriends stayed celebrate th birthdays. pla...

# %%
#Preprocessing and preparing the dataset
def pre_process(text):
# convert to lowercase
  text = str(text).lower()

  # remove all special characters and keep only alpha numeric characters and spaces
  text = re.sub(r'[^A-Za-z0-9\s.]',r'',text)

  #remove new lines
  text = re.sub(r'\n',r' ',text)

  # remove stop words
  text = " ".join([word for word in text.split() if word not in stopWords])

  return text

# %%
pre_process(data[0][50])
# Out:
# 'agree fancy. everything needed. breakfast pool hot tub nice shuttle airport later checkout time. noise issue tough sleep through. awhile forget noisy door nearby noisy guests. complained management later email credit compd us amount requested would return.'

# %%
data[0] = data[0].map(lambda x: pre_process(x))

# %%
data[0][1].split('.')[:5]
# Out:
# ['stayed crown plaza april april ',
#  ' staff friendly attentive',
#  ' elevators tiny ',
#  ' food restaurant delicious priced little high side',
#  ' course washington dc']

# %%
#convert the list of data into a list of lists
corpus = []
for line in data[0][1].split('.'):
  words = [x for x in line.split()]
  corpus.append(words)

# %%
corpus[:2]
# Out:
# [['stayed', 'crown', 'plaza', 'april', 'april'],
#  ['staff', 'friendly', 'attentive']]

# %%
#Convert the whole text in our dataset to a list of lists
data = data[0].map(lambda x: x.split('.'))
corpus = []
for i in (range(len(data))):
  for line in data[i]:
    words = [x for x in line.split()]
    corpus.append(words)

# %%
corpus[:2]
# Out:
# [['room', 'kind', 'clean', 'strong', 'smell', 'dogs'],
#  ['generally', 'average', 'ok', 'overnight', 'stay', 'youre', 'fussy']]

# %%
#collect all the words that occur together and adds an underscore between them
phrases = Phrases(sentences=corpus,min_count=25,threshold=50)
bigram = Phraser(phrases)
for index,sentence in enumerate(corpus):
  corpus[index] = bigram[sentence]

# %%
corpus[111]
# Out:
# ['connected', 'rivercenter', 'mall', 'downtown', 'san_antonio']

# %%
corpus[9]
# Out:
# ['course', 'washington_dc']

# %% [markdown]
# # Building the model

# %%
size = 100
window_size = 2
epochs = 100
min_count = 2
workers = 4
sg = 1 #sg=1 implies we use the skip-gram model for training, sg=0 implies we use CBOW model

# %%
model = Word2Vec(corpus,sg=1,window=window_size,vector_size=size,min_count=min_count,workers=workers,epochs=epochs)

# %%
model.save('/content/word2vec.model')

# %%
model = Word2Vec.load('/content/word2vec.model')

# %%
#Evaluating the embeddings
model.wv.most_similar('san_diego')
# Out:
# [('san_antonio', 0.7938194870948792),
#  ('san_francisco', 0.7419612407684326),
#  ('phoenix', 0.7353970408439636),
#  ('austin', 0.7346410155296326),
#  ('dallas', 0.7320181131362915),
#  ('memphis', 0.7246792316436768),
#  ('indianapolis', 0.723918080329895),
#  ('seattle', 0.7199681401252747),
#  ('boston', 0.7106994390487671),
#  ('sf', 0.7094084620475769)]

# %%
model.wv.most_similar(positive=['woman', 'king'], negative=['man'], topn=1)
# Out:
# [('queen', 0.6972159743309021)]

# %%
text = ['los_angeles','indianapolis', 'holiday', 'san_antonio','new_york']
model.wv.doesnt_match(text)
# Out:
# 'holiday'

# %% [markdown]
# # Visualizing word embeddings in TensorBoard

# %%
import tensorflow.compat.v1 as tf
from tensorboard.plugins import projector
import numpy as np

import gensim
import os

# %%
file_name = "/content/word2vec.model"
model = gensim.models.keyedvectors.KeyedVectors.load(file_name)

# %%
max_size = len(model.wv)-1

# %%
w2v = np.zeros((max_size,model.layer1_size))

# %%
if not os.path.exists('projections'):
  os.makedirs('projections')
with open("projections/metadata.tsv", 'w+') as file_metadata:
  for i, word in enumerate(model.wv.index_to_key[:max_size]):
    #store the embeddings of the word
    w2v[i] = model.wv[word]
    #write the word to a file
    file_metadata.write(word + '\n')

# %%
sess = tf.InteractiveSession()

# %%
embedding = tf.Variable(w2v, trainable=False, name='embedding')

# %%
tf.disable_eager_execution()

# %%
tf.global_variables_initializer().run()

# %%
saver = tf.train.Saver()

# %%
writer = tf.summary.FileWriter('projections', sess.graph)

# %%
config = projector.ProjectorConfig()
embed = config.embeddings.add()

# %%
embed.tensor_name = 'embedding'
embed.metadata_path = 'metadata.tsv'

# %%
projector.visualize_embeddings(writer, config)
saver.save(sess, 'projections/model.ckpt', global_step=max_size)
# Out:
# 'projections/model.ckpt-28070'

# %%
# %load_ext tensorboard
# %tensorboard --logdir=projections --port=8000

# %% [markdown]
# # Doc2vec

# %%
from gensim.models.doc2vec import TaggedDocument
from nltk import RegexpTokenizer
from nltk.corpus import stopwords
tokenizer = RegexpTokenizer(r'\w+')
stopWords = set(stopwords.words('english'))

# %%
# !unzip /content/news_dataset.zip

# %%
import os

docLabels = [f for f in os.listdir('/content/news_dataset') if f.endswith('.txt')]
data = []

for doc in docLabels:
    with open('/content/news_dataset/' + doc, 'r', encoding='latin-1') as file:
        file_content = file.read()
        data.append(file_content)

# %%
docLabels[:5]
# Out:
# ['Electronics_313.txt',
#  'Science_552.txt',
#  'Electronics_513.txt',
#  'Electronics_662.txt',
#  'Sports_659.txt']

# %%
class DocIterator(object):
  def __init__(self, doc_list, labels_list):
    self.labels_list = labels_list
    self.doc_list = doc_list
  def __iter__(self):
    for idx, doc in enumerate(self.doc_list):
      yield TaggedDocument(words=doc.split(), tags=[self.labels_list[idx]])

# %%
it = DocIterator(data, docLabels)

# %%
size = 100
alpha = 0.025
min_alpha = 0.025
dm = 1
min_count = 1
epochs = 100

# %%
model = gensim.models.Doc2Vec(vector_size=size, min_count=min_count, alpha=alpha, min_alpha=min_alpha, dm=dm, epochs=epochs)
model.build_vocab(it)

# %%
for epoch in range(10):
  model.train(it,total_examples=120,epochs=model.epochs)
  model.alpha -= 0.002
  model.min_alpha = model.alpha
# Out:
# WARNING:gensim.models.word2vec:EPOCH 0: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 1: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 2: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 3: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 4: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 5: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 6: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 7: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 8: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 9: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 10: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 11: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 12: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 13: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 14: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 15: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 16: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 17: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 18: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 19: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 20: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 21: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 22: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 23: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 24: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 25: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 26: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 27: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 28: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 29: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 30: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 31: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 32: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 33: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 34: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 35: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 36: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 37: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 38: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 39: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 40: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 41: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 42: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 43: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 44: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 45: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 46: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 47: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 48: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 49: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 50: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 51: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 52: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 53: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 54: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 55: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 56: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 57: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 58: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 59: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 60: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 61: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 62: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 63: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 64: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 65: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 66: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 67: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 68: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 69: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 70: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 71: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 72: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 73: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 74: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 75: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 76: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 77: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 78: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 79: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 80: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 81: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 82: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 83: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 84: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 85: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 86: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 87: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 88: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 89: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 90: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 91: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 92: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 93: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 94: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 95: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 96: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 97: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 98: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 99: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 0: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 1: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 2: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 3: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 4: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 5: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 6: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 7: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 8: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 9: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 10: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 11: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 12: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 13: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 14: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 15: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 16: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 17: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 18: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 19: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 20: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 21: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 22: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 23: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 24: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 25: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 26: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 27: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 28: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 29: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 30: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 31: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 32: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 33: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 34: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 35: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 36: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 37: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 38: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 39: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 40: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 41: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 42: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 43: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 44: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 45: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 46: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 47: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 48: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 49: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 50: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 51: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 52: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 53: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 54: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 55: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 56: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 57: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 58: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 59: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 60: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 61: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 62: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 63: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 64: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 65: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 66: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 67: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 68: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 69: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 70: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 71: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 72: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 73: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 74: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 75: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 76: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 77: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 78: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 79: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 80: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 81: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 82: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 83: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 84: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 85: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 86: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 87: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 88: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 89: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 90: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 91: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 92: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 93: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 94: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 95: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 96: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 97: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 98: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 99: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 0: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 1: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 2: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 3: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 4: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 5: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 6: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 7: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 8: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 9: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 10: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 11: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 12: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 13: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 14: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 15: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 16: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 17: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 18: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 19: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 20: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 21: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 22: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 23: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 24: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 25: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 26: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 27: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 28: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 29: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 30: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 31: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 32: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 33: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 34: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 35: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 36: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 37: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 38: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 39: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 40: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 41: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 42: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 43: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 44: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 45: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 46: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 47: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 48: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 49: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 50: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 51: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 52: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 53: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 54: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 55: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 56: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 57: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 58: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 59: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 60: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 61: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 62: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 63: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 64: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 65: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 66: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 67: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 68: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 69: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 70: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 71: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 72: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 73: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 74: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 75: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 76: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 77: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 78: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 79: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 80: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 81: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 82: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 83: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 84: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 85: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 86: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 87: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 88: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 89: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 90: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 91: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 92: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 93: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 94: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 95: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 96: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 97: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 98: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 99: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 0: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 1: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 2: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 3: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 4: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 5: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 6: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 7: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 8: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 9: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 10: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 11: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 12: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 13: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 14: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 15: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 16: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 17: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 18: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 19: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 20: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 21: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 22: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 23: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 24: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 25: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 26: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 27: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 28: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 29: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 30: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 31: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 32: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 33: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 34: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 35: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 36: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 37: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 38: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 39: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 40: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 41: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 42: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 43: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 44: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 45: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 46: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 47: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 48: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 49: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 50: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 51: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 52: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 53: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 54: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 55: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 56: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 57: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 58: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 59: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 60: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 61: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 62: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 63: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 64: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 65: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 66: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 67: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 68: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 69: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 70: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 71: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 72: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 73: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 74: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 75: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 76: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 77: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 78: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 79: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 80: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 81: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 82: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 83: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 84: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 85: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 86: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 87: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 88: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 89: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 90: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 91: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 92: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 93: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 94: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 95: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 96: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 97: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 98: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 99: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 0: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 1: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 2: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 3: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 4: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 5: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 6: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 7: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 8: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 9: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 10: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 11: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 12: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 13: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 14: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 15: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 16: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 17: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 18: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 19: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 20: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 21: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 22: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 23: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 24: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 25: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 26: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 27: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 28: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 29: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 30: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 31: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 32: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 33: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 34: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 35: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 36: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 37: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 38: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 39: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 40: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 41: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 42: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 43: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 44: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 45: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 46: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 47: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 48: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 49: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 50: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 51: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 52: supplied example count (4000) did not equal expected count (120)
# ...
# WARNING:gensim.models.word2vec:EPOCH 49: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 50: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 51: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 52: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 53: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 54: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 55: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 56: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 57: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 58: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 59: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 60: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 61: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 62: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 63: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 64: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 65: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 66: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 67: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 68: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 69: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 70: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 71: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 72: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 73: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 74: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 75: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 76: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 77: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 78: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 79: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 80: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 81: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 82: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 83: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 84: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 85: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 86: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 87: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 88: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 89: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 90: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 91: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 92: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 93: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 94: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 95: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 96: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 97: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 98: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 99: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 0: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 1: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 2: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 3: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 4: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 5: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 6: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 7: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 8: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 9: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 10: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 11: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 12: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 13: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 14: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 15: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 16: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 17: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 18: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 19: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 20: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 21: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 22: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 23: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 24: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 25: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 26: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 27: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 28: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 29: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 30: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 31: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 32: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 33: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 34: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 35: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 36: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 37: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 38: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 39: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 40: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 41: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 42: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 43: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 44: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 45: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 46: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 47: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 48: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 49: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 50: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 51: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 52: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 53: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 54: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 55: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 56: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 57: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 58: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 59: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 60: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 61: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 62: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 63: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 64: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 65: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 66: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 67: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 68: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 69: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 70: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 71: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 72: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 73: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 74: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 75: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 76: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 77: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 78: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 79: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 80: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 81: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 82: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 83: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 84: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 85: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 86: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 87: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 88: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 89: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 90: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 91: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 92: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 93: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 94: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 95: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 96: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 97: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 98: supplied example count (4000) did not equal expected count (120)
# WARNING:gensim.models.word2vec:EPOCH 99: supplied example count (4000) did not equal expected count (120)

# %%
model.save('/content/doc2vec.model')

# %%
d2v_model = gensim.models.doc2vec.Doc2Vec.load('/content/doc2vec.model')

# %%
d2v_model.docvecs.most_similar('Sports_1.txt')
# Out:
# [('Politics_994.txt', 0.6021988391876221),
#  ('Sports_360.txt', 0.592275857925415),
#  ('Sports_555.txt', 0.5828407406806946),
#  ('Sports_407.txt', 0.5800635814666748),
#  ('Sports_324.txt', 0.5778862237930298),
#  ('Sports_723.txt', 0.5773323774337769),
#  ('Sports_323.txt', 0.5717895030975342),
#  ('Sports_480.txt', 0.5717713236808777),
#  ('Sports_918.txt', 0.5717670321464539),
#  ('Sports_424.txt', 0.566116213798523)]
